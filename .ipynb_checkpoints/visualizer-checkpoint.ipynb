# %%
import numpy as np
import plotly.graph_objects as go

# Using readlines() 
file1 = open('summer_winter/other_data/loss_log.txt', 'r') 
Lines = file1.readlines() 
  
count = 1
index2 = []

#loss data
ggan = []
g_l1 = []
d_real = []
d_fake = []

epoch = []

time = 0

for line in Lines: 
    res = line.split()   
    ep = res[1]
    ep = ep[:-1]
    
    t = res[1]
    t = t[:-1]
    time = time + float(t) 
    epoch.append(int(ep))
    
    #read data
    ggan.append(float(res[9]))
    g_l1.append(float(res[11]))
    d_real.append(float(res[13]))
    d_fake.append(float(res[15]))
    
    index2.append(count)
    count = count + 1


control = epoch[0]  
epochs = []  
epoch_count = 0
for i in range(len(epoch)):
    if epoch[i] != control:
        epoch_count = epoch_count + 1
        epochs.append(epoch_count)
        control = epoch[i]
        
epochs = np.asarray(epochs, dtype=int)
index2 = np.asarray(index2, dtype=float)

index2 = index2 / 135


# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=index2, y=g_l1,
                    mode='lines',
                    name='GL1'))
fig.add_trace(go.Scatter(x=index2, y=ggan,
                    mode='lines',
                    name='GGAN'))
fig.add_trace(go.Scatter(x=index2, y=d_real,
                    mode='lines',
                    name='D_Real'))
fig.add_trace(go.Scatter(x=index2, y=d_fake,
                    mode='lines',
                    name='D_Fake'))

fig.show()

hours = time/3600
seconds = time % 3600
#print("Hours: "+ str(hours) + " seconds: " + str(seconds))
# Out:
# <div>                            <div id="0c9e8520-07d3-48b1-b720-d2c9a89f7560" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c9e8520-07d3-48b1-b720-d2c9a89f7560")) {                    Plotly.newPlot(                        "0c9e8520-07d3-48b1-b720-d2c9a89f7560",                        [{"mode": "lines", "name": "GL1", "type": "scatter", "x": [0.007407407407407408, 0.014814814814814815, 0.022222222222222223, 0.02962962962962963, 0.037037037037037035, 0.044444444444444446, 0.05185185185185185, 0.05925925925925926, 0.06666666666666667, 0.07407407407407407, 0.08148148148148149, 0.08888888888888889, 0.0962962962962963, 0.1037037037037037, 0.1111111111111111, 0.11851851851851852, 0.1259259259259259, 0.13333333333333333, 0.14074074074074075, 0.14814814814814814, 0.15555555555555556, 0.16296296296296298, 0.17037037037037037, 0.17777777777777778, 0.18518518518518517, 0.1925925925925926, 0.2, 0.2074074074074074, 0.21481481481481482, 0.2222222222222222, 0.22962962962962963, 0.23703703703703705, 0.24444444444444444, 0.2518518518518518, 0.25925925925925924, 0.26666666666666666, 0.2740740740740741, 0.2814814814814815, 0.28888888888888886, 0.2962962962962963, 0.3037037037037037, 0.3111111111111111, 0.31851851851